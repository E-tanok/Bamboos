# %%
import pandas as pd
import numpy as np

# %%
from bamboos import Bamboos

# %%
df_metadatas = pd.read_csv('columns_metadatas.csv', sep=';')
L_data_schema = list(df_metadatas['column_name'])
df_metadatas.head(10)
# Out:
#                   column_name    datatype
# 0                         age  continuous
# 1             class_of_worker     nominal
# 2    detailed_industry_recode     nominal
# 3  detailed_occupation_recode     nominal
# 4                   education     nominal
# 5               wage_per_hour  continuous
# 6  enroll_in_edu_inst_last_wk     nominal
# 7                marital_stat     nominal
# 8         major_industry_code     nominal
# 9       major_occupation_code     nominal

# %%
df_train = pd.read_csv('census_income_learn.csv', names=L_data_schema)
df_train.head(10)
# Out:
#    age                  class_of_worker  detailed_industry_recode  \
# 0   73                  Not in universe                         0
# 1   58   Self-employed-not incorporated                         4
# 2   18                  Not in universe                         0
# 3    9                  Not in universe                         0
# 4   10                  Not in universe                         0
# 5   48                          Private                        40
# 6   42                          Private                        34
# 7   28                          Private                         4
# 8   47                 Local government                        43
# 9   34                          Private                         4
#
#    detailed_occupation_recode                    education  wage_per_hour  \
# 0                           0         High school graduate              0
# 1                          34   Some college but no degree              0
# 2                           0                   10th grade              0
# 3                           0                     Children              0
# 4                           0                     Children              0
# 5                          10   Some college but no degree           1200
# 6                           3   Bachelors degree(BA AB BS)              0
# 7                          40         High school graduate              0
# 8                          26   Some college but no degree            876
# 9                          37   Some college but no degree              0
#
#   enroll_in_edu_inst_last_wk                      marital_stat  \
# 0            Not in universe                           Widowed
# 1            Not in universe                          Divorced
# 2                High school                     Never married
# 3            Not in universe                     Never married
# 4            Not in universe                     Never married
# 5            Not in universe   Married-civilian spouse present
# 6            Not in universe   Married-civilian spouse present
# 7            Not in universe                     Never married
# 8            Not in universe   Married-civilian spouse present
# 9            Not in universe   Married-civilian spouse present
#
#                   major_industry_code                   major_occupation_code  \
# 0         Not in universe or children                         Not in universe
# 1                        Construction     Precision production craft & repair
# 2         Not in universe or children                         Not in universe
# 3         Not in universe or children                         Not in universe
# 4         Not in universe or children                         Not in universe
# 5                       Entertainment                  Professional specialty
# 6   Finance insurance and real estate          Executive admin and managerial
# 7                        Construction            Handlers equip cleaners etc
# 8                           Education          Adm support including clerical
# 9                        Construction   Machine operators assmblrs & inspctrs
#
#       ...      country_of_birth_father country_of_birth_mother  \
# 0     ...                United-States           United-States
# 1     ...                United-States           United-States
# 2     ...                      Vietnam                 Vietnam
# 3     ...                United-States           United-States
# 4     ...                United-States           United-States
# 5     ...                  Philippines           United-States
# 6     ...                United-States           United-States
# 7     ...                United-States           United-States
# 8     ...                United-States           United-States
# 9     ...                United-States           United-States
#
#   country_of_birth_self                           citizenship  \
# 0         United-States     Native- Born in the United States
# 1         United-States     Native- Born in the United States
# 2               Vietnam   Foreign born- Not a citizen of U S
# 3         United-States     Native- Born in the United States
# 4         United-States     Native- Born in the United States
# 5         United-States     Native- Born in the United States
# 6         United-States     Native- Born in the United States
# 7         United-States     Native- Born in the United States
# 8         United-States     Native- Born in the United States
# 9         United-States     Native- Born in the United States
#
#   own_business_or_self_employed fill_inc_questionnaire_for_veteran's_admin  \
# 0                             0                            Not in universe
# 1                             0                            Not in universe
# 2                             0                            Not in universe
# 3                             0                            Not in universe
# 4                             0                            Not in universe
# 5                             2                            Not in universe
# 6                             0                            Not in universe
# 7                             0                            Not in universe
# 8                             0                            Not in universe
# 9                             0                            Not in universe
#
#    veterans_benefits  weeks_worked_in_year  year income_level
# 0                  2                     0    95     - 50000.
# 1                  2                    52    94     - 50000.
# 2                  2                     0    95     - 50000.
# 3                  0                     0    94     - 50000.
# 4                  0                     0    94     - 50000.
# 5                  2                    52    95     - 50000.
# 6                  2                    52    94     - 50000.
# 7                  2                    30    95     - 50000.
# 8                  2                    52    95     - 50000.
# 9                  2                    52    94     - 50000.
#
# [10 rows x 42 columns]

# %%
bamboos = Bamboos(df_train)
cols_caracs = bamboos.get_cols_caracs()
cols_caracs
# Out:
# c:\python\python36\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                            step_id step_label col_datatype  \
# age                                              0       init        int64
# age                                              0       init        int64
# capital_gains                                    0       init        int64
# capital_losses                                   0       init        int64
# citizenship                                      0       init       object
# class_of_worker                                  0       init       object
# country_of_birth_father                          0       init       object
# country_of_birth_mother                          0       init       object
# country_of_birth_self                            0       init       object
# detailed_household_and_family_stat               0       init       object
# detailed_household_summary_in_household          0       init       object
# detailed_industry_recode                         0       init        int64
# detailed_occupation_recode                       0       init        int64
# dividends_from_stocks                            0       init        int64
# education                                        0       init       object
# enroll_in_edu_inst_last_wk                       0       init       object
# family_members_under_18                          0       init       object
# fill_inc_questionnaire_for_veteran's_admin       0       init       object
# full_or_part_time_employment_stat                0       init       object
# hispanic_origin                                  0       init       object
# ignore                                           0       init      float64
# income_level                                     0       init       object
# live_in_this_house_1_year_ago                    0       init       object
# major_industry_code                              0       init       object
# major_occupation_code                            0       init       object
# marital_stat                                     0       init       object
# member_of_a_labor_union                          0       init       object
# migration_code-change_in_msa                     0       init       object
# migration_code-change_in_reg                     0       init       object
# migration_code-move_within_reg                   0       init       object
# migration_prev_res_in_sunbelt                    0       init       object
# num_persons_worked_for_employer                  0       init        int64
# own_business_or_self_employed                    0       init        int64
# race                                             0       init       object
# reason_for_unemployment                          0       init       object
# region_of_previous_residence                     0       init       object
# sex                                              0       init       object
# state_of_previous_residence                      0       init       object
# tax_filer_stat                                   0       init       object
# veterans_benefits                                0       init        int64
# wage_per_hour                                    0       init        int64
# weeks_worked_in_year                             0       init        int64
# year                                             0       init        int64
#
#                                            completion_ratio unique_ratio
# age                                                       1  0.000456088
# age                                                       1  0.000456088
# capital_gains                                             1  0.000661578
# capital_losses                                            1  0.000566351
# citizenship                                               1  2.50598e-05
# class_of_worker                                           1  4.51076e-05
# country_of_birth_father                                   1  0.000215514
# country_of_birth_mother                                   1  0.000215514
# country_of_birth_self                                     1  0.000215514
# detailed_household_and_family_stat                        1  0.000190454
# detailed_household_summary_in_household                   1  4.00956e-05
# detailed_industry_recode                                  1  0.000260622
# detailed_occupation_recode                                1  0.000235562
# dividends_from_stocks                                     1   0.00740767
# education                                                 1  8.52032e-05
# enroll_in_edu_inst_last_wk                                1  1.50359e-05
# family_members_under_18                                   1  2.50598e-05
# fill_inc_questionnaire_for_veteran's_admin                1  1.50359e-05
# full_or_part_time_employment_stat                         1  4.00956e-05
# hispanic_origin                                           1  5.01195e-05
# ignore                                                    1     0.500193
# income_level                                              1  1.00239e-05
# live_in_this_house_1_year_ago                             1  1.50359e-05
# major_industry_code                                       1  0.000120287
# major_occupation_code                                     1  7.51793e-05
# marital_stat                                              1  3.50837e-05
# member_of_a_labor_union                                   1  1.50359e-05
# migration_code-change_in_msa                              1  5.01195e-05
# migration_code-change_in_reg                              1  4.51076e-05
# migration_code-move_within_reg                            1  5.01195e-05
# migration_prev_res_in_sunbelt                             1  2.00478e-05
# num_persons_worked_for_employer                           1  3.50837e-05
# own_business_or_self_employed                             1  1.50359e-05
# race                                                      1  2.50598e-05
# reason_for_unemployment                                   1  3.00717e-05
# region_of_previous_residence                              1  3.00717e-05
# sex                                                       1  1.00239e-05
# state_of_previous_residence                               1   0.00025561
# tax_filer_stat                                            1  3.00717e-05
# veterans_benefits                                         1  1.50359e-05
# wage_per_hour                                             1   0.00621482
# weeks_worked_in_year                                      1  0.000265634
# year                                                      1  1.00239e-05

# %%
bamboos.flag_one_step('removing_column_ignore', df_train)
# Out:
# flagging : removing_column_ignore
# c:\python\python36\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
